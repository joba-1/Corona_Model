# %% [markdown]
# # Things I had to do in the terminal before being able to use this notebook
#
#
# ## Use conda to build Python env with osmnx as main so that not upto date version in dependancies used but workable for osmnx
#
# conda config --prepend channels conda-forge
#
# conda create -n ox --strict-channel-priority osmnx
#
# ## go into env
# conda activate ox
#
# ## install other libs that are needed for visulization
# conda install matplotlib
# conda install numpy
# conda install -c anaconda ipykernel
#
# ## makes conda env into a kernel which then can be used by jupyter notebook
# python -m ipykernel install --user --name=ox
#
# ## other Tool for queries to OpenStreetMap in testing phase
# pip install OSMPythonTools

# %%
import osmnx as ox
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-b995e04b2481> in <module>
# ----> 1 import osmnx as ox
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#       5
#
# ModuleNotFoundError: No module named 'osmnx'

# %%
# Specify the name that is used to seach for the data
place_name = "Wedding, Berlin, Germany"

# Fetch OSM street network from the location
graph = ox.graph_from_place(place_name)

# %%
# Plot the streets
fig, ax = ox.plot_graph(graph)

# %% [markdown]
# Link for amenities:
# https://wiki.openstreetmap.org/wiki/Key:amenity#Healthcare

# %%
buildings_of_interest = ['clinic',
                         'doctors',
                         'nursing_home',
                         'pharmacy',
                         'social_facility',
                         'hospital',
                         'school',
                         'kindergarten',
                         'university',
                         'library',
                         'marketplace']
#get all the interesting amenity in the place of interest. !!BEWARE!! not all buildings have amenity so supermarket is separate query
bois = ox.pois_from_place(place_name, amenities=buildings_of_interest)

# %%
bois
# Out:
#                osmid                                           geometry  \
# 251737915  251737915                          POINT (13.34983 52.54973)
# 268915173  268915173                          POINT (13.34962 52.53988)
# 268915206  268915206                          POINT (13.36077 52.56020)
# 268915280  268915280                          POINT (13.36272 52.54299)
# 268915319  268915319                          POINT (13.34343 52.55624)
# ...              ...                                                ...
# 525385367  525385367  POLYGON ((13.36494 52.55522, 13.36487 52.55560...
# 639108961  639108961  POLYGON ((13.37164 52.53780, 13.37217 52.53805...
# 705175020  705175020  POLYGON ((13.34359 52.54557, 13.34330 52.54542...
# 712173438  712173438  POLYGON ((13.36597 52.54881, 13.36590 52.54886...
# 2728323      2728323  MULTIPOLYGON (((13.33993 52.54173, 13.33994 52...
#
#           addr:city addr:country addr:housenumber addr:postcode  \
# 251737915    Berlin           DE               99         13353
# 268915173       NaN          NaN              NaN           NaN
# 268915206       NaN          NaN              NaN           NaN
# 268915280    Berlin          NaN               5B         13353
# 268915319    Berlin           DE               25         13349
# ...             ...          ...              ...           ...
# 525385367    Berlin           DE               74         13347
# 639108961       NaN          NaN              NaN           NaN
# 705175020       NaN          NaN              NaN           NaN
# 712173438       NaN          NaN              NaN           NaN
# 2728323         NaN          NaN                1         13353
#
#                 addr:street          amenity dispensing email  ...  ref:isil  \
# 251737915         Seestraße         pharmacy        yes   NaN  ...       NaN
# 268915173               NaN     kindergarten        NaN   NaN  ...       NaN
# 268915206               NaN     kindergarten        NaN   NaN  ...       NaN
# 268915280   Willdenowstraße          doctors        NaN   NaN  ...       NaN
# 268915319  Glasgower Straße     kindergarten        NaN   NaN  ...       NaN
# ...                     ...              ...        ...   ...  ...       ...
# 525385367         Seestraße           school        NaN   NaN  ...       NaN
# 639108961               NaN           school        NaN   NaN  ...       NaN
# 705175020               NaN       university        NaN   NaN  ...       NaN
# 712173438               NaN  social_facility        NaN   NaN  ...       NaN
# 2728323          Weststraße          library        NaN   NaN  ...  DE-578-3
#
#           indoor  ref room source:name school:for alt_name          type  \
# 251737915    NaN  NaN  NaN         NaN        NaN      NaN           NaN
# 268915173    NaN  NaN  NaN         NaN        NaN      NaN           NaN
# 268915206    NaN  NaN  NaN         NaN        NaN      NaN           NaN
# 268915280    NaN  NaN  NaN         NaN        NaN      NaN           NaN
# 268915319    NaN  NaN  NaN         NaN        NaN      NaN           NaN
# ...          ...  ...  ...         ...        ...      ...           ...
# 525385367    NaN  NaN  NaN         NaN        NaN      NaN           NaN
# 639108961    NaN  NaN  NaN         NaN        NaN      NaN           NaN
# 705175020    NaN  NaN  NaN         NaN        NaN      NaN           NaN
# 712173438    NaN  NaN  NaN         NaN        NaN      NaN           NaN
# 2728323      NaN  NaN  NaN         NaN        NaN      NaN  multipolygon
#
#                             ways addr:housename
# 251737915                    NaN            NaN
# 268915173                    NaN            NaN
# 268915206                    NaN            NaN
# 268915280                    NaN            NaN
# 268915319                    NaN            NaN
# ...                          ...            ...
# 525385367                    NaN            NaN
# 639108961                    NaN            NaN
# 705175020                    NaN            NaN
# 712173438                    NaN            NaN
# 2728323    [203286024, 26773609]        Forum 1
#
# [215 rows x 102 columns]

# %%
#extra just for hospitals for nicer visulisation
boish = ox.pois_from_place(place_name, amenities=['hospital'])
#boisr = ox.pois_from_place(place_name, shop=)

# %%
boish
# Out:
#                  osmid                                           geometry  \
# 311411895    311411895                          POINT (13.34339 52.53942)
# 2268083434  2268083434                          POINT (13.33963 52.54018)
# 2309794985  2309794985                          POINT (13.34534 52.54501)
# 2836037697  2836037697                          POINT (13.33882 52.54319)
# 2838303238  2838303238                          POINT (13.36579 52.55456)
# 5020547105  5020547105                          POINT (13.33862 52.54089)
# 5081271437  5081271437                          POINT (13.33815 52.54122)
# 6623052077  6623052077                          POINT (13.34472 52.54476)
# 4750929        4750929  POLYGON ((13.34035 52.54247, 13.33911 52.54334...
# 137033906    137033906  POLYGON ((13.36570 52.55506, 13.36242 52.55547...
#
#            access   access:conditional barrier bicycle foot horse  \
# 311411895      no  yes @ (05:00-17:00)    gate     yes  yes    no
# 2268083434     no                  NaN    gate     NaN  NaN   NaN
# 2309794985    NaN  yes @ (05:00-17:00)    gate     yes  yes    no
# 2836037697    NaN                  NaN     NaN     NaN  NaN   NaN
# 2838303238    NaN                  NaN     NaN     NaN  NaN   NaN
# 5020547105    NaN  yes @ (05:00-17:00)    gate     yes  yes    no
# 5081271437     no  yes @ (05:00-17:00)    gate     yes  yes   NaN
# 6623052077    NaN                  NaN    gate     NaN  NaN   NaN
# 4750929       NaN                  NaN     NaN     NaN  NaN   NaN
# 137033906     NaN                  NaN     NaN     NaN  NaN   NaN
#
#            motor_vehicle                                   name  ...  \
# 311411895             no         Tor E, Einfahrt Nordufer 21/22  ...
# 2268083434           NaN                                    NaN  ...
# 2309794985            no     Charité Ausfahrt Amrumer Straße 29  ...
# 2836037697           NaN                                    NaN  ...
# 2838303238           NaN                                    NaN  ...
# 5020547105            no                Eingang Sylter Straße 3  ...
# 5081271437           NaN                                  Tor F  ...
# 6623052077           NaN         Charité Zugang Ost-West-Straße  ...
# 4750929              NaN        Charité Campus Virchow Klinikum  ...
# 137033906            NaN  Evangelisches Geriatriezentrum Berlin  ...
#
#                             website wheelchair wheelchair:description  \
# 311411895                       NaN        NaN                    NaN
# 2268083434                      NaN        NaN                    NaN
# 2309794985                      NaN        NaN                    NaN
# 2836037697                      NaN        NaN                    NaN
# 2838303238                      NaN        NaN                    NaN
# 5020547105                      NaN        NaN                    NaN
# 5081271437                      NaN        NaN                    NaN
# 6623052077                      NaN        NaN                    NaN
# 4750929     https://www.charite.de/        yes                    NaN
# 137033906       http://www.egzb.de/    limited                    NaN
#
#             wikidata emergency                      wikipedia contact:phone  \
# 311411895        NaN       NaN                            NaN           NaN
# 2268083434       NaN       NaN                            NaN           NaN
# 2309794985       NaN       NaN                            NaN           NaN
# 2836037697       NaN       NaN                            NaN           NaN
# 2838303238       NaN       NaN                            NaN           NaN
# 5020547105       NaN       NaN                            NaN           NaN
# 5081271437       NaN       NaN                            NaN           NaN
# 6623052077       NaN       NaN                            NaN           NaN
# 4750929     Q2172279       yes  de:Rudolf-Virchow-Krankenhaus           NaN
# 137033906        NaN       NaN                            NaN           NaN
#
#            landuse healthcare:speciality short_name
# 311411895      NaN                   NaN        NaN
# 2268083434     NaN                   NaN        NaN
# 2309794985     NaN                   NaN        NaN
# 2836037697     NaN                   NaN        NaN
# 2838303238     NaN                   NaN        NaN
# 5020547105     NaN                   NaN        NaN
# 5081271437     NaN                   NaN        NaN
# 6623052077     NaN                   NaN        NaN
# 4750929        NaN                   NaN        NaN
# 137033906      NaN            geriatrics       EGZB
#
# [10 rows x 34 columns]

# %%
#new query for all buildings in place of interest data similar but not identical...
buildings = ox.footprints_from_place(place_name)
#bos = buildings[buildings['amenity'].isin(buildings_of_interest)]
#separation to get all shops for nicer visualization
shop = buildings[buildings.shop.notnull()]

# %%
#make geopandas of place of interest
#whole area
area = ox.gdf_from_place(place_name)
#basically all the ways one can move on !!BEWARE!! to my knowledge also not streets
nodes, edges = ox.graph_to_gdfs(graph)

# %%
fig, ax = plt.subplots(figsize=(25,16))

# Plot the footprint
area.plot(ax=ax, facecolor='black')

# Plot street edges
edges.plot(ax=ax, linewidth=1, edgecolor='#BC8F8F')

# Plot buildings of interest and shops
bois.plot(ax=ax, facecolor='khaki', alpha=0.7)
shop.plot(ax=ax, facecolor='red', alpha=0.7)

# Plot hospitals
boish.plot(ax=ax, color='green', alpha=0.7, markersize=10)
plt.tight_layout()

# %%
#idea check to see if ox.pois_from_place(place_name, amenities=buildings_of_interest) and ox.footprints_from_place(place_name) 
#do the same not finished but they are not, for Wedding!
bos = buildings[buildings['amenity'].isin(buildings_of_interest)]
bos
# Out:
#                                                        nodes addr:city  \
# 26750488   [3178668898, 3178668820, 3178668785, 317866873...       NaN
# 44419969   [5374064037, 564642837, 564642836, 2298418694,...       NaN
# 53163711   [672790367, 5374064031, 5374064032, 2298418696...    Berlin
# 100946116  [3178997189, 3178997182, 3178997186, 317899718...       NaN
# 104394630  [4209046633, 4209046630, 4209046629, 120440997...    Berlin
# 111660202  [1271608568, 1271608695, 1271608712, 127160861...    Berlin
# 312054418  [3178668363, 3178668361, 293417346, 293417335,...       NaN
# 362827350  [3670763923, 6221048177, 3670763924, 127059725...    Berlin
# 639108961  [6022629424, 6022629423, 6022629422, 602262942...       NaN
# 2728323                                                  NaN       NaN
#
#           addr:country addr:housenumber addr:postcode        addr:street  \
# 26750488           NaN              NaN         13349                NaN
# 44419969           NaN              NaN           NaN                NaN
# 53163711            DE               37         13347        Antonstraße
# 100946116          NaN              NaN           NaN                NaN
# 104394630           DE               10         13351       Dohnagestell
# 111660202           DE               38         13349  Edinburger Straße
# 312054418          NaN              NaN         13349                NaN
# 362827350           DE              149         13353       Müllerstraße
# 639108961          NaN              NaN           NaN                NaN
# 2728323            NaN                1         13353         Weststraße
#
#           addr:suburb          amenity building building:colour  ...  \
# 26750488          NaN           school      yes             NaN  ...
# 44419969          NaN           school      yes             NaN  ...
# 53163711      Wedding           school      yes             NaN  ...
# 100946116         NaN     kindergarten      yes             NaN  ...
# 104394630     Wedding  social_facility      yes             NaN  ...
# 111660202     Wedding     kindergarten      yes             NaN  ...
# 312054418         NaN           school      yes             NaN  ...
# 362827350     Wedding          library   public             NaN  ...
# 639108961         NaN           school      yes             NaN  ...
# 2728323           NaN          library      yes             NaN  ...
#
#           substation construction man_made backrest material elevator landuse  \
# 26750488         NaN          NaN      NaN      NaN      NaN      NaN     NaN
# 44419969         NaN          NaN      NaN      NaN      NaN      NaN     NaN
# 53163711         NaN          NaN      NaN      NaN      NaN      NaN     NaN
# 100946116        NaN          NaN      NaN      NaN      NaN      NaN     NaN
# 104394630        NaN          NaN      NaN      NaN      NaN      NaN     NaN
# 111660202        NaN          NaN      NaN      NaN      NaN      NaN     NaN
# 312054418        NaN          NaN      NaN      NaN      NaN      NaN     NaN
# 362827350        NaN          NaN      NaN      NaN      NaN      NaN     NaN
# 639108961        NaN          NaN      NaN      NaN      NaN      NaN     NaN
# 2728323          NaN          NaN      NaN      NaN      NaN      NaN     NaN
#
#                                            members          type opening_date
# 26750488                                       NaN           NaN          NaN
# 44419969                                       NaN           NaN          NaN
# 53163711                                       NaN           NaN          NaN
# 100946116                                      NaN           NaN          NaN
# 104394630                                      NaN           NaN          NaN
# 111660202                                      NaN           NaN          NaN
# 312054418                                      NaN           NaN          NaN
# 362827350                                      NaN           NaN          NaN
# 639108961                                      NaN           NaN          NaN
# 2728323    {203286024: 'inner', 26773609: 'outer'}  multipolygon          NaN
#
# [10 rows x 134 columns]

# %%
shop = buildings[buildings.shop.notnull()]
#shop['shop'].unique()

# %%
#start of different idea to access OpenStreetMap and retrive data
#aĺlows to make own queries with more variables than ameniety so longterm better solution
from OSMPythonTools.nominatim import Nominatim
#get area data by area name. very convenient
nominatim = Nominatim()
#get area data here id by area name
areaId = nominatim.query('Berlin, Germany').areaId()
areaId
# Out:
# 3600062422

# %%
#here the query for the buildings will happen
from OSMPythonTools.overpass import overpassQueryBuilder, Overpass
buildings_of_interest = ['clinic',
                         'doctors',
                         'nursing_home',
                         'pharmacy',
                         'social_facility',
                         'hospital',
                         'school',
                         'kindergarten',
                         'university',
                         'library',
                         'marketplace']
#overpass is the nicest api to use, at least there were examples for this tool
overpass = Overpass()
#query to api, saddly right now only one selector possible but idea is to loop or find help
query = overpassQueryBuilder(area=areaId, elementType=['node','way', 'relation'], selector='"amenity"="hospital"', includeGeometry=True)
#saves data as some kind of formated list
result = overpass.query(query)
result

# %%
import geopandas as gpd
#in result.elements list of the actual things. to my understanding in GeoJson format hope is that geopanda can use them
result.elements()[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-24508a5a8e55> in <module>
#       1 import geopandas as gpd
#       2 #in result.elements list of the actual things. to my understanding in GeoJson format hope is that geopanda can use them
# ----> 3 result.elements()[1]
#
# NameError: name 'result' is not defined
