# %%
import parse_schedule as ps

# %%
file_name = 'schedules_standard'
schedule = ps.parse_schedule(file_name)
schedule
# Out:
#   18.0 0 [7]
#   18.0 0 [7, 7]
#   18.0 0 [7, 7, 5]
#   18.0 0 [7, 7, 5, 0]
#   67.0 0 [7, 7, 5, 0, 7]
#   67.0 0 [7, 7, 5, 0, 7, 7]
#   8
#   18
#   67.0 0 [7, 7, 5, 0, 7, 7, 5]
#   1
#   19
#   67.0 0 [7, 7, 5, 0, 7, 7, 5, 0]
#   inf 0 [7, 7, 5, 0, 7, 7, 5, 0, 7]
#   inf 0 [7, 7, 5, 0, 7, 7, 5, 0, 7, 7]
#   2
#   11
#   inf 0 [7, 7, 5, 0, 7, 7, 5, 0, 7, 7, 0]
#   inf 1 [7, 7, 5, 0, 7, 7, 5, 0, 7, 7, 0, 7]
#   inf 1 [7, 7, 5, 0, 7, 7, 5, 0, 7, 7, 0, 7, 7]
#   4
#   12
# {18.0: [[{'times': [8,
#      31,
#      55,
#      79,
#      104,
#      133,
#      156,
#      13,
#      37,
#      61,
#      86,
#      111,
#      141,
#      162,
#      21,
#      43,
#      66,
#      90,
#      117],
#     'locs': ['school',
#      'school',
#      'school',
#      'school',
#      'school',
#      'public_4',
#      'public_5',
#      'public_1',
#      'public_2',
#      'public_3',
#      'public_1',
#      'public_3',
#      'home',
#      'home',
#      'home',
#      'home',
# ...
